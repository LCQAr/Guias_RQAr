# %%
# Parameters
UF = "AC"

# %% [markdown]
# # Seção 3.1 — Distribuição espacial
#
# Este notebook reproduz a tabela 6 e a figura 23 da seção 3.1 do Relatório Anual de Qualidade do Ar

# %% [markdown]
# LEIA ATENTAMENTE ANTES DE EXECUTAR ESTE  SCRIPT
#
# 1. ATUALIZAÇÃO DOS CAMINHOS:
#
#    Este código precisa saber em qual pasta do seu computador o projeto está salvo.
#    Como cada computador possui uma estrutura de pastas diferente, você deve
#    atualizar a variável de caminho bruto (quando indicado) para
#    apontar para o diretório correto na sua máquina antes de rodar o script.
#
#
# 2. PRESERVAÇÃO DA ESTRUTURA DE PASTAS:
#
#    Este código funciona de forma integrada com as demais pastas, scripts e
#    arquivos auxiliares exatamente na ORGANIZAÇÃO fornecida no projeto.
#
#    -> Não mova arquivos ou pastas de lugar.
#
#    -> Não altere o nome dos diretórios ou arquivos.
#
#    Caso a estrutura fornecida seja alterada, as importações e chamadas de dados
#    irão falhar e o código não irá funcionar.

# %% [markdown]
# ### Tabela 6 — Número de estações de monitoramento por UF, categoria e status
#
# Tabela que cruza, para cada Unidade Federativa (UF), o número de estações de monitoramento
# por categoria (Indicativa, Referência, Não declarado) e status de operação
# (Ativa, Inativa, Não declarado).
#
# Os dados são lidos de `Monitoramento_QAr_BR.csv`, deduplicados por `ID_OEMA`
# e organizados em uma tabela pivotada com uma linha de total para o Brasil (BR).

# %%
import pandas as pd
aqmData = pd.read_csv('https://arquivos.lcqar.ufsc.br/data/databases/stations/Monitoramento_QAr_BR.csv')
mapping_df = pd.read_csv('https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/data/dicionarios/CODIGO_POLUENTES_HTML.csv')
path_bandeiras = 'https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/'

# %%
# Esta célula depende do módulo flagTables.py (função `table06MMA()`), que por sua vez requer o arquivo `Monitoramento_QAr_BR.csv`

# Importações necessárias
import flagTables as flagtab
import importlib; importlib.reload(flagtab)
html_table6 = flagtab.table06MMA(aqmData, UF, path_bandeiras)
# Out:
# <style type="text/css">
# #T_b9cd1 th {
#   text-align: center;
#   vertical-align: middle;
#   font-size: 8pt;
#   background-color: white;
#   color: black;
# }
# #T_b9cd1 td > img {
#   max-width: unset;
# }
# #T_b9cd1 th[colspan] {
#   border-bottom: 1px solid #ccc;
#   font-weight: bold;
#   text-transform: uppercase;
# }
# #T_b9cd1_row0_col0, #T_b9cd1_row0_col1, #T_b9cd1_row0_col2, #T_b9cd1_row0_col3, #T_b9cd1_row0_col4, #T_b9cd1_row0_col5, #T_b9cd1_row0_col6, #T_b9cd1_row0_col7, #T_b9cd1_row0_col8, #T_b9cd1_row0_col9, #T_b9cd1_row0_col10, #T_b9cd1_row2_col0, #T_b9cd1_row2_col1, #T_b9cd1_row2_col2, #T_b9cd1_row2_col3, #T_b9cd1_row2_col4, #T_b9cd1_row2_col5, #T_b9cd1_row2_col6, #T_b9cd1_row2_col7, #T_b9cd1_row2_col8, #T_b9cd1_row2_col9, #T_b9cd1_row2_col10, #T_b9cd1_row3_col0, #T_b9cd1_row3_col1, #T_b9cd1_row3_col2, #T_b9cd1_row3_col3, #T_b9cd1_row3_col4, #T_b9cd1_row3_col5, #T_b9cd1_row3_col6, #T_b9cd1_row3_col7, #T_b9cd1_row3_col8, #T_b9cd1_row3_col9, #T_b9cd1_row3_col10 {
#   background-color: white;
#   color: black;
#   font-size: 11px;
#   text-align: center;
# }
# #T_b9cd1_row1_col0, #T_b9cd1_row1_col2, #T_b9cd1_row1_col3, #T_b9cd1_row1_col4, #T_b9cd1_row1_col5, #T_b9cd1_row1_col6, #T_b9cd1_row1_col7, #T_b9cd1_row1_col8, #T_b9cd1_row1_col9, #T_b9cd1_row1_col10 {
#   background-color: white;
#   color: black;
#   font-size: 11px;
# }
# #T_b9cd1_row1_col1 {
#   background-color: white;
#   color: black;
#   font-size: 11px;
#   text-align: left;
#   font-weight: bold;
#   font-size: 12px;
# }
# </style>
# <table id="T_b9cd1">
#   <thead>
#     <tr>
#       <th id="T_b9cd1_level0_col0" class="col_heading level0 col0" colspan="2"></th>
#       <th id="T_b9cd1_level0_col2" class="col_heading level0 col2" colspan="3">Indicativa</th>
#       <th id="T_b9cd1_level0_col5" class="col_heading level0 col5" colspan="3">Referência</th>
#       <th id="T_b9cd1_level0_col8" class="col_heading level0 col8" colspan="3">Não declarado</th>
#     </tr>
#     <tr>
#       <th id="T_b9cd1_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_b9cd1_level1_col1" class="col_heading level1 col1" >UF</th>
#       <th id="T_b9cd1_level1_col2" class="col_heading level1 col2" >Ativa</th>
#       <th id="T_b9cd1_level1_col3" class="col_heading level1 col3" >Inativa</th>
#       <th id="T_b9cd1_level1_col4" class="col_heading level1 col4" >Não declarado</th>
#       <th id="T_b9cd1_level1_col5" class="col_heading level1 col5" >Ativa</th>
#       <th id="T_b9cd1_level1_col6" class="col_heading level1 col6" >Inativa</th>
#       <th id="T_b9cd1_level1_col7" class="col_heading level1 col7" >Não declarado</th>
#       <th id="T_b9cd1_level1_col8" class="col_heading level1 col8" >Ativa</th>
#       <th id="T_b9cd1_level1_col9" class="col_heading level1 col9" >Inativa</th>
#       <th id="T_b9cd1_level1_col10" class="col_heading level1 col10" >Não declarado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b9cd1_row0_col0" class="data row0 col0" ></td>
#       <td id="T_b9cd1_row0_col1" class="data row0 col1" ></td>
#       <td id="T_b9cd1_row0_col2" class="data row0 col2" ></td>
#       <td id="T_b9cd1_row0_col3" class="data row0 col3" ></td>
#       <td id="T_b9cd1_row0_col4" class="data row0 col4" ></td>
#       <td id="T_b9cd1_row0_col5" class="data row0 col5" ></td>
#       <td id="T_b9cd1_row0_col6" class="data row0 col6" ></td>
#       <td id="T_b9cd1_row0_col7" class="data row0 col7" ></td>
#       <td id="T_b9cd1_row0_col8" class="data row0 col8" ></td>
#       <td id="T_b9cd1_row0_col9" class="data row0 col9" ></td>
#       <td id="T_b9cd1_row0_col10" class="data row0 col10" ></td>
#     </tr>
#     <tr>
#       <td id="T_b9cd1_row1_col0" class="data row1 col0" ></td>
#       <td id="T_b9cd1_row1_col1" class="data row1 col1" ><b>Norte</b></td>
#       <td id="T_b9cd1_row1_col2" class="data row1 col2" ></td>
#       <td id="T_b9cd1_row1_col3" class="data row1 col3" ></td>
#       <td id="T_b9cd1_row1_col4" class="data row1 col4" ></td>
#       <td id="T_b9cd1_row1_col5" class="data row1 col5" ></td>
#       <td id="T_b9cd1_row1_col6" class="data row1 col6" ></td>
#       <td id="T_b9cd1_row1_col7" class="data row1 col7" ></td>
#       <td id="T_b9cd1_row1_col8" class="data row1 col8" ></td>
#       <td id="T_b9cd1_row1_col9" class="data row1 col9" ></td>
#       <td id="T_b9cd1_row1_col10" class="data row1 col10" ></td>
#     </tr>
#     <tr>
#       <td id="T_b9cd1_row2_col0" class="data row2 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras//AC.png" width="30"></td>
#       <td id="T_b9cd1_row2_col1" class="data row2 col1" >AC</td>
#       <td id="T_b9cd1_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_b9cd1_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_b9cd1_row2_col4" class="data row2 col4" >-</td>
#       <td id="T_b9cd1_row2_col5" class="data row2 col5" >-</td>
#       <td id="T_b9cd1_row2_col6" class="data row2 col6" >-</td>
#       <td id="T_b9cd1_row2_col7" class="data row2 col7" >-</td>
#       <td id="T_b9cd1_row2_col8" class="data row2 col8" >-</td>
#       <td id="T_b9cd1_row2_col9" class="data row2 col9" >-</td>
#       <td id="T_b9cd1_row2_col10" class="data row2 col10" >-</td>
#     </tr>
#     <tr>
#       <td id="T_b9cd1_row3_col0" class="data row3 col0" ></td>
#       <td id="T_b9cd1_row3_col1" class="data row3 col1" ></td>
#       <td id="T_b9cd1_row3_col2" class="data row3 col2" ></td>
#       <td id="T_b9cd1_row3_col3" class="data row3 col3" ></td>
#       <td id="T_b9cd1_row3_col4" class="data row3 col4" ></td>
#       <td id="T_b9cd1_row3_col5" class="data row3 col5" ></td>
#       <td id="T_b9cd1_row3_col6" class="data row3 col6" ></td>
#       <td id="T_b9cd1_row3_col7" class="data row3 col7" ></td>
#       <td id="T_b9cd1_row3_col8" class="data row3 col8" ></td>
#       <td id="T_b9cd1_row3_col9" class="data row3 col9" ></td>
#       <td id="T_b9cd1_row3_col10" class="data row3 col10" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Salvar a tabela interativo como um arquivo HTML e abrir no navegador
import webbrowser
import os

output_dir = "outputs"
output_path = os.path.join(output_dir, "Tabela.6.html")

os.makedirs(output_dir, exist_ok=True)

with open(output_path, "w", encoding="utf-8") as f:
    f.write(html_table6)

webbrowser.open(output_path)
# Out:
# False

# %% [markdown]
# ### Fig. 23 — Distribuição espacial das estações de monitoramento por status
#
# Mapa interativo apresentando as estações ativas  inativas, e a localização geográfica de cada estação de monitoramento da qualidade do ar.
#
# As estações são coloridas conforme o status de operação: verde para ativa, vermelho para inativa e cinza para não declarado.
#
# Ao passar o mouse sobre cada ponto, são exibidas informações: ID OEMA e status.
# Ao clicar no ponto são exibidas: ID_OEMA, status, categoria, finalidade, calibração, método, marca, modelo,  poluentes monitorados e número de poluentes medidos

# %%
pip install geobr
# Out:
# Requirement already satisfied: geobr in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (1.0.0)
# Requirement already satisfied: geopandas<=1.1.2,>=1.0.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (1.1.1)
# Requirement already satisfied: shapely<=2.1.0,>=1.7.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (2.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (2.32.4)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (2.5.0)
# Requirement already satisfied: lxml<7.0.0,>=5.1.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (6.0.0)
# Requirement already satisfied: html5lib==1.1 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (1.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (21.0.0)
# Requirement already satisfied: duckdb>=1.5.3 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (1.5.5)
# Requirement already satisfied: rapidfuzz>=3.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geobr) (3.14.1)
# Requirement already satisfied: six>=1.9 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from html5lib==1.1->geobr) (1.17.0)
# Requirement already satisfied: webencodings in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from html5lib==1.1->geobr) (0.5.1)
# Requirement already satisfied: numpy>=1.24 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geopandas<=1.1.2,>=1.0.0->geobr) (2.2.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geopandas<=1.1.2,>=1.0.0->geobr) (0.11.0)
# Requirement already satisfied: packaging in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geopandas<=1.1.2,>=1.0.0->geobr) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geopandas<=1.1.2,>=1.0.0->geobr) (2.3.0)
# Requirement already satisfied: pyproj>=3.5.0 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from geopandas<=1.1.2,>=1.0.0->geobr) (3.7.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.25.1->geobr) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.25.1->geobr) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.25.1->geobr) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas<=1.1.2,>=1.0.0->geobr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas<=1.1.2,>=1.0.0->geobr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nobre/Notebooks/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas<=1.1.2,>=1.0.0->geobr) (2025.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Esta célula depende do módulo scripts/spatialFigures.py(função spatial_rede_monitoramento_new()),
# que requer os dados de Monitoramento_QAr_BR.csv com as colunas de localização (latitude/longitude) preenchidas.

# Importações necessárias
import sys
import os

project_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, project_path)

import scripts.spatialFigures as spaFig
import importlib; importlib.reload(spaFig)
from matplotlib.colors import ListedColormap

# Tooltips exibidos ao passar o mouse sobre cada estação no mapa
tooltips = ["ID_OEMA", "STATUS", "POLUENTE", "N° Poluentes Medidos", "CATEGORIA", "OPERACAO"]

# Cores por status: Ativa = verde, Inativa = vermelho, Não declarado = cinza
cmap = ListedColormap(["green", "red", 'gray'])

m = spaFig.spatial_rede_monitoramento_states(aqmData, UF, "STATUS", tooltips, cmap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_944c02150f4527caec8d41c5a81f84ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend STATUS&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;STATUS&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#008000&#x27;&gt;&lt;/span&gt;Ativa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Inativa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#808080&#x27;&gt;&lt;/span&gt;Não declarado&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_944c02150f4527caec8d41c5a81f84ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_944c02150f4527caec8d41c5a81f84ff = L.map(
#                 &quot;map_944c02150f4527caec8d41c5a81f84ff&quot;,
#                 {
#                     center: [-9.128692923000001, -70.30702209299999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_944c02150f4527caec8d41c5a81f84ff);
#
#
#
#
#
#             var tile_layer_0d04341a62f1832a06ee0b6488b209d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&q

# %%
# Salvar o mapa interativo como um arquivo HTML e abrir no navegador
import webbrowser

output_dir = "outputs"
output_path = os.path.join(output_dir, "Figura.23.html")

os.makedirs(output_dir, exist_ok=True)

m.save(output_path)

webbrowser.open(output_path)
# Out:
# False
