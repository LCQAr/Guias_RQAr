# %% [markdown]
# # Seção 1.2 — Origem dos dados
#
# Este notebook reproduz a figura 1 da seção 1.2 do Relatório Anual de Qualidade do Ar

# %% [markdown]
# LEIA ATENTAMENTE ANTES DE EXECUTAR ESTE  SCRIPT
#
# 1. ATUALIZAÇÃO DOS CAMINHOS:
#
#    Este código precisa saber em qual pasta do seu computador o projeto está salvo.
#    Como cada computador possui uma estrutura de pastas diferente, você deve
#    atualizar a variável de caminho bruto (quando indicado) para
#    apontar para o diretório correto na sua máquina antes de rodar o script.
#
#
# 2. PRESERVAÇÃO DA ESTRUTURA DE PASTAS:
#
#    Este código funciona de forma integrada com as demais pastas, scripts e
#    arquivos auxiliares exatamente na ORGANIZAÇÃO fornecida no projeto.
#
#    -> Não mova arquivos ou pastas de lugar.
#
#    -> Não altere o nome dos diretórios ou arquivos.
#
#    Caso a estrutura fornecida seja alterada, as importações e chamadas de dados
#    irão falhar e o código não irá funcionar.

# %% [markdown]
# ### Figura 1 — Origem das informações sobre o monitoramento da qualidade do ar pelos OEMAs

# %%
import pandas as pd
aqmData = pd.read_csv('https://arquivos.lcqar.ufsc.br/data/databases/stations/Monitoramento_QAr_BR.csv')
path_bandeiras = 'https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/'

# %%
# Esta célula depende do módulo flagTables.py (função `table06MMA()`), que por sua vez requer o arquivo `Monitoramento_QAr_BR.csv`

# Importações necessárias
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import secao_3.flagTables as flagtab
import importlib; importlib.reload(flagtab)

html_tabela1 = flagtab.table01(aqmData, path_bandeiras)
# Out:
# <style type="text/css">
# #T_5d36e th {
#   text-align: center;
# }
# #T_5d36e td > img {
#   max-width: unset;
# }
# #T_5d36e_row0_col0, #T_5d36e_row0_col1, #T_5d36e_row0_col2, #T_5d36e_row0_col3, #T_5d36e_row1_col0, #T_5d36e_row1_col1, #T_5d36e_row1_col2, #T_5d36e_row1_col3, #T_5d36e_row9_col0, #T_5d36e_row9_col1, #T_5d36e_row9_col2, #T_5d36e_row9_col3, #T_5d36e_row10_col0, #T_5d36e_row10_col1, #T_5d36e_row10_col2, #T_5d36e_row10_col3, #T_5d36e_row20_col0, #T_5d36e_row20_col1, #T_5d36e_row20_col2, #T_5d36e_row20_col3, #T_5d36e_row21_col0, #T_5d36e_row21_col1, #T_5d36e_row21_col2, #T_5d36e_row21_col3, #T_5d36e_row26_col0, #T_5d36e_row26_col1, #T_5d36e_row26_col2, #T_5d36e_row26_col3, #T_5d36e_row27_col0, #T_5d36e_row27_col1, #T_5d36e_row27_col2, #T_5d36e_row27_col3, #T_5d36e_row32_col0, #T_5d36e_row32_col1, #T_5d36e_row32_col2, #T_5d36e_row32_col3, #T_5d36e_row33_col0, #T_5d36e_row33_col1, #T_5d36e_row33_col2, #T_5d36e_row33_col3, #T_5d36e_row37_col0, #T_5d36e_row37_col1, #T_5d36e_row37_col2, #T_5d36e_row37_col3 {
#   background-color: white;
#   color: black;
#   text-align: center;
#   font-weight: bold;
#   font-size: 11px;
# }
# #T_5d36e_row2_col0, #T_5d36e_row2_col1, #T_5d36e_row2_col2, #T_5d36e_row2_col3, #T_5d36e_row3_col0, #T_5d36e_row3_col1, #T_5d36e_row3_col2, #T_5d36e_row3_col3, #T_5d36e_row4_col0, #T_5d36e_row4_col1, #T_5d36e_row4_col2, #T_5d36e_row4_col3, #T_5d36e_row5_col0, #T_5d36e_row5_col1, #T_5d36e_row5_col2, #T_5d36e_row5_col3, #T_5d36e_row6_col0, #T_5d36e_row6_col1, #T_5d36e_row6_col2, #T_5d36e_row6_col3, #T_5d36e_row7_col0, #T_5d36e_row7_col1, #T_5d36e_row7_col2, #T_5d36e_row7_col3, #T_5d36e_row8_col0, #T_5d36e_row8_col1, #T_5d36e_row8_col2, #T_5d36e_row8_col3, #T_5d36e_row11_col0, #T_5d36e_row11_col1, #T_5d36e_row11_col2, #T_5d36e_row11_col3, #T_5d36e_row12_col0, #T_5d36e_row12_col1, #T_5d36e_row12_col2, #T_5d36e_row12_col3, #T_5d36e_row13_col0, #T_5d36e_row13_col1, #T_5d36e_row13_col2, #T_5d36e_row13_col3, #T_5d36e_row14_col0, #T_5d36e_row14_col1, #T_5d36e_row14_col2, #T_5d36e_row14_col3, #T_5d36e_row15_col0, #T_5d36e_row15_col1, #T_5d36e_row15_col2, #T_5d36e_row15_col3, #T_5d36e_row16_col0, #T_5d36e_row16_col1, #T_5d36e_row16_col2, #T_5d36e_row16_col3, #T_5d36e_row17_col0, #T_5d36e_row17_col1, #T_5d36e_row17_col2, #T_5d36e_row17_col3, #T_5d36e_row18_col0, #T_5d36e_row18_col1, #T_5d36e_row18_col2, #T_5d36e_row18_col3, #T_5d36e_row19_col0, #T_5d36e_row19_col1, #T_5d36e_row19_col2, #T_5d36e_row19_col3, #T_5d36e_row22_col0, #T_5d36e_row22_col1, #T_5d36e_row22_col2, #T_5d36e_row22_col3, #T_5d36e_row23_col0, #T_5d36e_row23_col1, #T_5d36e_row23_col2, #T_5d36e_row23_col3, #T_5d36e_row24_col0, #T_5d36e_row24_col1, #T_5d36e_row24_col2, #T_5d36e_row24_col3, #T_5d36e_row25_col0, #T_5d36e_row25_col1, #T_5d36e_row25_col2, #T_5d36e_row25_col3, #T_5d36e_row28_col0, #T_5d36e_row28_col1, #T_5d36e_row28_col2, #T_5d36e_row28_col3, #T_5d36e_row29_col0, #T_5d36e_row29_col1, #T_5d36e_row29_col2, #T_5d36e_row29_col3, #T_5d36e_row30_col0, #T_5d36e_row30_col1, #T_5d36e_row30_col2, #T_5d36e_row30_col3, #T_5d36e_row31_col0, #T_5d36e_row31_col1, #T_5d36e_row31_col2, #T_5d36e_row31_col3, #T_5d36e_row34_col0, #T_5d36e_row34_col1, #T_5d36e_row34_col2, #T_5d36e_row34_col3, #T_5d36e_row35_col0, #T_5d36e_row35_col1, #T_5d36e_row35_col2, #T_5d36e_row35_col3, #T_5d36e_row36_col0, #T_5d36e_row36_col1, #T_5d36e_row36_col2, #T_5d36e_row36_col3 {
#   background-color: #F5F5F5;
#   color: black;
#   text-align: center;
#   font-size: 11px;
# }
# </style>
# <table id="T_5d36e">
#   <thead>
#     <tr>
#       <th id="T_5d36e_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_5d36e_level0_col1" class="col_heading level0 col1" >UF</th>
#       <th id="T_5d36e_level0_col2" class="col_heading level0 col2" >UF possui algum tipo de monitoramento?</th>
#       <th id="T_5d36e_level0_col3" class="col_heading level0 col3" >Fonte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d36e_row0_col0" class="data row0 col0" ></td>
#       <td id="T_5d36e_row0_col1" class="data row0 col1" ></td>
#       <td id="T_5d36e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_5d36e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row1_col0" class="data row1 col0" ></td>
#       <td id="T_5d36e_row1_col1" class="data row1 col1" >Norte</td>
#       <td id="T_5d36e_row1_col2" class="data row1 col2" ></td>
#       <td id="T_5d36e_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row2_col0" class="data row2 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/AC.png" width="30"></td>
#       <td id="T_5d36e_row2_col1" class="data row2 col1" >AC</td>
#       <td id="T_5d36e_row2_col2" class="data row2 col2" >Sim</td>
#       <td id="T_5d36e_row2_col3" class="data row2 col3" >PurpleAir 2025, Coleta interna</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row3_col0" class="data row3 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/AP.png" width="30"></td>
#       <td id="T_5d36e_row3_col1" class="data row3 col1" >AP</td>
#       <td id="T_5d36e_row3_col2" class="data row3 col2" >Sim</td>
#       <td id="T_5d36e_row3_col3" class="data row3 col3" >PurpleAir 2025</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row4_col0" class="data row4 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/AM.png" width="30"></td>
#       <td id="T_5d36e_row4_col1" class="data row4 col1" >AM</td>
#       <td id="T_5d36e_row4_col2" class="data row4 col2" >Sim</td>
#       <td id="T_5d36e_row4_col3" class="data row4 col3" >PurpleAir 2025</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row5_col0" class="data row5 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/PA.png" width="30"></td>
#       <td id="T_5d36e_row5_col1" class="data row5 col1" >PA</td>
#       <td id="T_5d36e_row5_col2" class="data row5 col2" >Sim</td>
#       <td id="T_5d36e_row5_col3" class="data row5 col3" >PurpleAir 2025, MonitorAr</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row6_col0" class="data row6 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/RO.png" width="30"></td>
#       <td id="T_5d36e_row6_col1" class="data row6 col1" >RO</td>
#       <td id="T_5d36e_row6_col2" class="data row6 col2" >Sim</td>
#       <td id="T_5d36e_row6_col3" class="data row6 col3" >PurpleAir 2025</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row7_col0" class="data row7 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/RR.png" width="30"></td>
#       <td id="T_5d36e_row7_col1" class="data row7 col1" >RR</td>
#       <td id="T_5d36e_row7_col2" class="data row7 col2" >Sim</td>
#       <td id="T_5d36e_row7_col3" class="data row7 col3" >PurpleAir 2025, Consulta 2025</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row8_col0" class="data row8 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/TO.png" width="30"></td>
#       <td id="T_5d36e_row8_col1" class="data row8 col1" >TO</td>
#       <td id="T_5d36e_row8_col2" class="data row8 col2" >Sim</td>
#       <td id="T_5d36e_row8_col3" class="data row8 col3" >PurpleAir 2025</td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row9_col0" class="data row9 col0" ></td>
#       <td id="T_5d36e_row9_col1" class="data row9 col1" ></td>
#       <td id="T_5d36e_row9_col2" class="data row9 col2" ></td>
#       <td id="T_5d36e_row9_col3" class="data row9 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row10_col0" class="data row10 col0" ></td>
#       <td id="T_5d36e_row10_col1" class="data row10 col1" >Nordeste</td>
#       <td id="T_5d36e_row10_col2" class="data row10 col2" ></td>
#       <td id="T_5d36e_row10_col3" class="data row10 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d36e_row11_col0" class="data row11 col0" ><img src= "https://arquivos.lcqar.ufsc.br/rqar-national-guide-files/_static/bandeiras/AL.png" width="30"></td>
#       <td id="T_5d36e_row11_col1" c

# %%
# Salvar a tabela interativo como um arquivo HTML e abrir no navegador
import webbrowser
import os

output_dir = "outputs"
output_path = os.path.join(output_dir, "tabela1.html")

os.makedirs(output_dir, exist_ok=True)

with open(output_path, "w", encoding="utf-8") as f:
    f.write(html_tabela1)

webbrowser.open(output_path)
# Out:
# True
